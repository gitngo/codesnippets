# %%
import nest_asyncio
nest_asyncio.apply()

from telethon import TelegramClient
from telethon.tl.functions.messages import GetHistoryRequest

api_id = 2431318
api_hash = '6f0a9ed2582bb334911c2915871fafb9'

client = TelegramClient('session_name', api_id, api_hash)

async def main():
    username = '@katiazawa'

    user = await client.get_entity(username)

    timestamps_history = []

    offset = 0
    has_messages = True
    while has_messages:
        history = await client(GetHistoryRequest(
            peer=user,
            limit=200,
            offset_date=None,
            offset_id=0,
            max_id=0,
            min_id=0,
            add_offset=offset,
            hash=0))

        has_messages = False
        for message in history.messages:
            has_messages = True
            timestamps_history.append((message.date, message.out, message.message))

        offset += len(history.messages)
        if offset % 1000 == 0:
            print(offset)




    def split_history_into_replicas(history):
        replicas = []


        print("messages size:", len(history))

        i = 0
        while i < len(history):
            replica = []
            while i < len(history) and history[i][1]:
                replica.append(history[i])
                i += 1
            if replica:
                replica.reverse()
                replicas.append(replica)

            replica = []
            while i < len(history) and not history[i][1]:
                replica.append(history[i])
                i += 1
            if replica:
                replica.reverse()
                replicas.append(replica)

        replicas.reverse()
        return replicas



    replicas = split_history_into_replicas(timestamps_history)

    her_diffs = []
    my_diffs = []

    for i in range(len(replicas) - 1):
        first_next = replicas[i + 1][0]
        last_current = replicas[i][-1]
        diff = first_next[0] - last_current[0]
        if last_current[2] and '?' in last_current[2]:
            print(last_current[2], '->', diff, '->', first_next[2])
            if last_current[1] and not first_next[1]:
                her_diffs.append(diff.seconds)
            else:
                my_diffs.append(diff.seconds)

    return (her_diffs, my_diffs)

async with client:
    diffs = client.loop.run_until_complete(main())
# Out:
# 1000
# 2000
# messages size: 2500
# На маяке ?) -> 0:00:22 -> Я уже подумал что ты Вера 😂
# Доброе) А я подумал ты в Маяке, так как у тебя в ТГ контент оттуда. Но в любом случае гипотеза что соседи подтвердилась)) Ну раз так, то грех не посидеть в какой нибудь ближайшей кафешке, как смотришь?) -> 0:16:03 -> Подожди, все верно я в маяке 😅
# Супер) Не будем откладывать в долгую, найдем часок сегодня? -> 0:01:45 -> Думаю да ,но в районе трех только где -то ,так как вечер уже занят
# У меня в 3 заканчивается звонок и я могу выдвинуться. Как тебе в 15:20 в Маяке? По месту на твой выбор, ты луче знаешь наверное) -> 0:02:06 -> Давай,там кстати со вчерашнего дня начался гастрофест и Прошутерия наша участвуют
# Это на вокзале,который ?) -> 0:59:59 -> Да 😂
# Привет. Я еду на турнир, во время матчей возможно буду не сильно на связи. Если что встречаемся прям там уже в кинотеатре у касс 21.20, норм? -> 0:11:27 -> Хорошоууу )Удачного турнира
# А ты как себя чувствуешь? -> 0:00:53 -> Ой я уже боюсь что то говорить. Как ты вчера назвала такое состояние когда заболеваешь но ещё не болеешь? 😂
# Ой я уже боюсь что то говорить. Как ты вчера назвала такое состояние когда заболеваешь но ещё не болеешь? 😂 -> 0:44:53 -> Продромальный период
# Огоо, подожди чего обидно? -> 0:01:56 -> Что проиграл на золотом тай-брейке моей ошибкой при счете 8:9
# А что за ошибка вышла? -> 0:02:47 -> Я у сетки бил по верхнему мячу неудобному, попал в сетку
# Как ты себя чувствуешь? Расклеенное состояние?) -> 0:17:53 -> Температура не большая, но нос вообще не дышит и горло очень дерет и слабость
# Ты как там? Может тебе что то из лекарств нужно? Соседи же, занесу) -> 0:00:07 -> А я сегодня не пошла никуда …
# Есть такое.. Я знал кому отправить)))
#
# Ну что, берем? Я бы рискнул, вероятность того что они вдруг будут раскуплены больше, чем вероятность что ты с позитивной динамикой не оклемаешься к пятнице и будет оч обидно потом если оба будем в форме но билетов уже не будет.. -> 1:43:37 -> Давай рисковать тогда 😌
# Ты любишь танцевать больше или сидеть ? -> 0:03:05 -> Мне кажется по вопросу я догадываюсь кто любит больше танцевать 😂😂😂
# Что думаешь? -> 0:00:18 -> А на танцполе можно его менять по желанию
# И что делать ? -> 0:00:00 -> А чем ты занимаешься?
# Так ты выходишь из дома? -> 0:00:02 -> Дома )))
# И как тебе? -> 0:00:20 -> Оуууу,тяжелый случай ! Я сейчас глянула ,действительно странно это де среда
# А пожары не смотрела ?) -> 0:01:06 -> Кстатиииии,надо посмотреть! Я как раз думала что глянуть вечерком
# Это не ты случайно реквест мне кинул сегодня ?)😏 -> 0:03:28 -> Оооо ты скачала Ракето 😁
# «Куда мы теперь» всмысле куда мы пойти ещё можем? На Паддингтона мне кажется после такого фильма как мы смотрели 😅 -> 0:00:17 -> Ты шутишь да ?)
# Ты шутишь да ?) -> 0:00:14 -> А ты куда хочешь?)
# А ты куда хочешь?) -> 0:01:23 -> Походу эта штука с рекомендациями и мемасиками работает в обе стороны ))
# Вообщем я следующим аудио сообщением записываю свое понимание мема. Только договариваемся что ты его не слушаешь а параллельно записываешь свое понимание. А затем одновременно слушаем друг друга. Для чистоты эксперимента, так сказать. Договорились?) -> 0:00:32 -> Блиииин,это копеечно очень продуманный подход
# А как так сделать ?) -> 0:00:12 -> Просто ты не слушаешь следующее мое аудио
# Думаешь у них ничего не получится ?? -> 0:00:53 -> Может уже не в инстаграме 🤣
# Ты после просмотра фильма под впечатлением и решила устроить digital detox? 😄 -> 2:30:16 ->
# Что спросить хотела? -> 0:03:39 -> Когда осознаешь еще что это не просто фантазия ,а на реальных событиях все… Да долго отходила )) На ночь нельзя такое смотреть
# https://www.instagram.com/reel/DCo88Vlyb4s/?igsh=MWZrMnRsbDl0MDNseQ== -> 1:09:57 -> Ох,я так улетела вчера ни о чем не думая, а сегодня ели проснулась пол часа назад 🫣
# Завтра есть такая возможность поиграть. Забронировал предварительно корт. Что скажешь? -> 0:07:58 -> Это я так понимаю самое раннее,что есть на завтра ?
# Салют) Как ты? Самочувствие ? -> 1:57:14 -> Привет) Вроде ничего уже ) Как сам ? Настроение?
# Привет) Вроде ничего уже ) Как сам ? Настроение? -> 0:02:06 -> Отлично, тогда по плану, играем в WIMC в 22. Настроение обычное. С пятничным конечно не сравнить:))
# Какой адрес ? -> 0:01:00 -> А я скорее всего успею за тобой заехать. У меня в 21 заканчивается теннис на другом конце города
# Ты точно будешь в ресурсе еще играть ?😅 -> 0:02:11 -> Конечно. Я бы не предлагал тебе если бы не был в ресурсе)
# Мы успеем за 20 минут ?) -> 0:01:39 -> 10 минут ехать туда и там 10 минут до матча. Норм
# У тебя же есть ракетка? 😺 -> 0:26:27 -> Est’ 🤘
# Есть эластичный бинт ? -> 0:06:51 -> Есть такая эластичная фиксирующая штука
# Его творчество или признавать творчество по национальному признаку ?) -> 0:00:11 -> Второе
# А пораньше ?? -> 0:00:13 -> Нету вроде
# Это Пол Мескал твой любимый актер ?🤔 -> 0:00:42 -> Не, Дензел Вашингтон 😎
# А на какое время смотришь ? -> 0:00:16 -> Вот на это
# Ну как там твой ушиб ? -> 0:22:57 -> Хромаю( Отменил теннис во вторник
# У меня обычно такие видосы в ленте )) https://www.instagram.com/reel/DCmRlWDv3EJ/?igsh=dWJ3Mjc2ZDJ0MGI= -> 0:09:11 -> Ты такого хочешь себе ?)
# Ты такого хочешь себе ?) -> 0:21:48 -> Нет)
# Такого https://www.instagram.com/reel/C_AsrIwidRY/?igsh=MXN4YTd0cHNlYXc0Ng== -> 2:30:15 -> Милые
# Ну что когда за щенком ?) -> 0:24:56 -> Уже лет 15 как собираюсь 😂😂
# Как твой день? Нормально вернулась в строй?) -> 0:02:16 ->
# Ну как?) -> 0:32:50 ->
# https://www.facebook.com/share/v/1EfEsbFt25/?mibextid=iCjFHx -> 0:44:05 -> Ой я не могуууу
# Как там твоя нога ? Спал отек ? -> 0:02:00 -> https://www.instagram.com/reel/C-vBaX7vr2q/?igsh=MXR3a3I1d2Uxcjl3cw==
# Дома будешь ? -> 0:12:32 -> Пока да
# На что?) -> 0:05:16 -> https://www.instagram.com/share/_dvWHY2Qa
# Так этот видос видела ты?) -> 0:00:51 ->
# Знаешь его ? -> 0:14:08 -> Not sure may be seen once or twice
# Катя я 15 минут выйти на связь пытаюсь не получается. Почему ты не можешь записать аудио обозначить свои планы? -> 0:12:56 -> Буду через 20 минут
# Это магазин в Дане? -> 0:02:15 -> И еще говорила,что с такой утренней панорамой  за окном предвкушаю открытие snowboardingseson
# В каком? 😃 -> 0:00:47 -> Около Синабона
# Этаж? -> 0:00:21 -> Где вход
# А ты где ? -> 0:01:19 -> None
# На такси все-таки поехал ? Или прогулялся ?) -> 0:01:00 -> Прогулялся:)
# Не холодно же ?) -> 0:00:09 -> Не, не холодно было
# Как ты кстати вчера сразу уснул ?) -> 0:02:07 -> Нет, мыслей полнилась голова)
# Тебе не ответили из гончарной мастерской кстати? -> 3:49:50 -> https://kolokolschool.by/?slideIndex=1
# Ну как чувствуешь себя ? Получше ? -> 0:41:41 -> Да нет, так же, пограничное состояние
# Дома ?) -> 0:01:27 -> Да
# А ты к чему спрашивала? Зайти хотела ?)) -> 17:17:25 -> https://www.instagram.com/share/BA1N9O6wOs
# The Million Lady? 😂😂 -> 0:00:58 ->
# Промыслителтно? -> 0:00:18 -> Да
# Ведунья? -> 1:12:41 -> Знающая
# Или плохо чувствуешь себя ? -> 0:00:01 -> Я тебя в гости жду же, мы так договаривались)
# Я бы может еды заказал бы какой-нибудь. Было бы здорово даже может приготовить что-то вместе, но мы не успеем пока доедешь итд. Есть предпочтения что заказать? -> 0:45:49 -> None
# Заказываю такси? -> 0:01:02 -> None
# Успела до прибытия брата?) -> 1:14:59 -> 2,5 написано … Да,надо попробовать )
# Такая нормально будет?) -> 1:04:40 -> Да. Любая. Но лучше сегодня одну шт перед матчем купить все равно
# Успел ?) -> 0:46:05 -> Да, все отлично!
# Закончила игру? Давай такси закажу как будешь готова -> 0:46:06 -> Дома )
# Как ты сегодня? В сон не клонило? -> 0:18:46 -> Только послушала кружок и поняла,что опять без звука тебе записала 🤦🏻‍♀️
# А ты как ? Противостоял Морфею или поддался в его царство ? -> 0:00:08 -> Поспал немного, да
# В 19-й ? -> 0:00:16 -> Да. Все норм кроме с-реактивного белка, повышенный, около 9
# А соэ какое ? -> 0:02:58 ->
# Хорошо,что пересдал, как раз месяц почти прошел,надо смотреть динамику.Раньше все хорошо было с холестерином и мочевой кислотой ? -> 0:00:44 -> Я не пересдавал. Только за результатами пошел
# Да ? -> 0:00:02 ->
# Это это видео ? -> 0:00:05 -> Да)
# На Москоу ? -> 0:00:43 -> На встречу
# Do you want to see me?:) -> 0:06:23 -> Если есть настрой - я готов его поддержать - встретимся, посидим в обнимку, посмотрим что нибудь нормальное на этот раз. но я и паузу готов взять сегодня.
# Both options are ok for me
# Почему на английском? Как будто кто-то другой вселился в тебя и пишет мне это) -> 0:01:30 -> You sound just like my mom :))
# Когда пойдем играть 🎾?! -> 0:05:01 -> Мы уже сколько раз доброй ночи желали друг другу? 😆😆
#
# Дааай будем честными - теннис не наша самая идеальная сторона времяпрепровождения. Плюс ещё сертификат в спа салон надо использовать 😉
# Как там встреча ? -> 0:00:07 -> Не отпускают ))
# А как тот трек назывался ? -> 0:08:34 -> Какой
# Medicine вроде ? -> 0:09:36 -> Да)
# Это трек так называется или это твои ощущения при прослушивании Medicine? -> 0:07:56 -> Ощщщщущчэээняяя
# Ты что там только проснулся ? -> 0:11:13 -> Ну может час назад, мисс хронометраж 😂
# А как нашла с кем играть? Ракето? -> 0:00:36 ->
# Как партнер на этот раз? ☺️ -> 0:08:41 -> Much better than the previous one
# Это почему ты так решил ?😅 -> 0:03:59 -> Можно посмотреть все примеры переключений на английский - и половина будет в такие моменты когда топик тебе неудобный или тебе не нравится мой ответ, короче когда тебе нужно framing the answer before letting it out
# Собрано! Готова? Заказываю такси -> 0:01:25 -> Да ☺️✨
# Ну как ты там успеваешь ?) -> 0:17:32 -> Не знаю. Луэечу на всех парах в аэропорт
# Ты шутишь ?? -> 0:00:31 -> Нет(
# Как так ? -> 0:00:06 -> Хз
# И что теперь ? -> 0:00:56 -> Не знаю
# Ты уже в аэропорту ? -> 0:05:28 -> Да
# А кушаааааать ?) -> 0:00:49 -> Заказал шаурму
# Ну как ты там долетел ? -> 0:08:23 -> Ага с мамой сидим
# А ты как там? -> 1:09:55 ->
# Как твои дела?) -> 2:31:58 -> Привееет ) Все отлично ,как у тебя ?
# Привееет ) Все отлично ,как у тебя ? -> 0:18:21 -> Да тоже норм) выспалась?
# Как проводишь день? -> 0:35:28 ->
# Сегодня уже нет тусовки ? -> 0:36:03 -> Сегодня очень узкий семейный круг. Три сестренки, два брата, мама, тетя дядя племянники и племянницы
# А я тебе говорил что я про него думаю? 😄 -> 0:00:49 -> Неа,вроде не говорил
# Доставка почтой типа ? 📦 -> 0:08:19 -> Ага сдек
# Надеюсь с таким настроением ?) -> 0:02:37 -> Честно? Меня этот седовласый старец не зацепил ни разу
# Жить ?) -> 0:00:01 -> Желание что то сделать
# Понимаю )) Возникло желание переехать обратно ? -> 1:08:59 -> Скорее как место силы
# К Москве? 🫶😝 -> 0:04:17 -> Ахахаха
# Ну как у тебя идет? -> 0:14:56 ->
# А ты когда прилетаешь то ? -> 0:00:14 -> В 3 ночи или около того
# 4:7 4:7 7:3, потом какие результаты были? -> 1:53:47 -> А потом 7:5 в мою пользу
# Какие планы ? Домой?) -> 0:07:34 -> Конечно))) Нет, тусить 🤣🤣
# Серьезно? -> 0:00:05 -> Да
# А где тусят в 03:45? ) -> 0:00:04 -> С ракеткой ,рюкзаком
# A ты в WIMC играешь ? -> 0:27:55 -> Это жидкость только. Жир так быстро не уходит
# Уже выехал ? -> 0:08:27 -> Да
# А что?))) Чувствую у тебя была какая то last minute idea 😝 -> 0:01:17 ->
# Ну как игра ?) -> 0:00:05 -> Шалом
# Сильно расстроился? -> 0:00:09 -> Да нет)
# Ты как посидела ? -> 0:01:50 -> Предположила
# Где решили посидеть? -> 0:04:06 ->
# Как настроение? -> 0:01:25 ->
# Что?)) -> 0:02:26 -> Тахрир 😅
# Мама приготовила? -> 0:02:02 -> Грин приготовил 😁
# А ты там над чем работаешь сейчас ?) -> 0:01:37 -> Над попыткой заснуть пораньше)
# Как ты ? -> 0:03:50 -> Хорошо) Соскучился) ты как?
# Хорошо) Соскучился) ты как? -> 0:10:56 -> Тоже хорошо,весь день в работке.. Вот через пол часа только заканчиваю )
# На чай?) -> 0:01:16 ->
# Ты тоже замечал,что не скидывается с инстаграма ?) -> 0:00:40 -> Нет, первый раз слышу
# Сальце ?)) -> 0:00:07 -> Да, шпик)
# https://www.kvitki.by/rus/bileti/teatr/teatr-imeni-mgorkogo/idiot-446696/
#
# Хочешь сходить? -> 0:06:11 -> Ну по Голландски заговорил 😂
# У тебя обычно нюдсы? 😈🤣 -> 0:02:28 ->
# Похожи ?) -> 0:00:58 -> О, фото части тела - уже теплее)))
# На кого собака похожа ?)) -> 0:00:10 -> На её реальный прототип
# Уедешь в сша?) -> 0:00:00 -> Прокачал же знатно
# Ты в аквамарине ? -> 0:02:35 -> Уже дома)
# Почему столько бутылок что это?) -> 0:06:42 -> Водичка
# А почему все в одном месте собраны?) -> 0:00:20 -> На столе ))
# У тебя кстати обувь чистая после вчерашней прогулки ?🤣 -> 0:00:03 -> 😂
# Тоже пахнет ? -> 0:00:10 -> Хз не нюхал)
# Dog shit?:) -> 0:00:04 -> Я походу наступила куда-то
# Смотришь его ? -> 0:00:00 -> На лбу 😄
# Мне советуешь ? -> 0:00:00 -> Шахтерское прошлое?)
# Смотрел такое ? -> 0:00:04 -> Ноуп
# Кстати у тебя были какие-то планы на выходные ?) -> 0:05:17 -> В субботу парный турнир с 15 до 17-18. Если проходим то в воскресенье тоже. Также в воскресенье возможно другой парный турнир еженедельный традиционный. Других планов нет.
#
# Tell me
# У кого др? -> 0:00:42 ->
# Это он ? -> 0:03:46 -> Да 🥰
# И как кстати суджук? Попробовала?) -> 0:11:01 -> Ахах,ну прикольненько )) Заскучать точно не успела за 15 минут ) Это не Чарли ,это Бруно и получи палкой 🥲 Какие люди на районе у него там,конечно – и смех и ужас.
# Как дела? -> 0:44:03 -> Ох,сегодня что-то ели проснулась ((
# Или это бесполезно?)) -> 0:11:17 -> елЕ *?
# елЕ *? -> 0:25:07 -> Да) Но я у меня в целом вопрос😙
# https://www.youtube.com/watch?v=nZtMvWxVnek -> 0:03:58 -> Чем занята? На учебе?
# Чем занята? На учебе? -> 0:31:40 -> Дааа )) Вот только закончила
# У тебя все хорошо? У меня какое то дурацкое чувство хрен пойми откуда оно -> 0:14:39 -> В плане чего ?)
# В плане чего ?) -> 0:06:09 -> Не знаю. Тревожность какая то)
# Вечером есть планы? Может погуляем на районе или в дана Молл -> 0:02:49 -> Можем )
# Во сколько?) -> 0:02:56 -> Часиков в 7-8 тебе как?
# Часиков в 7-8 тебе как? -> 0:24:41 -> Okey )
# А ты еще не видел инсталейшен новогоднюю в Дане ?) -> 0:01:43 -> Ноуп
# Ты к Дане подойдешь или домой ?) -> 0:00:52 -> Как тебе будет удобно
# Ок. Позже тогда чем 20:35? -> 0:12:54 -> Не)
# А ты как после тенниса,кайф ?) -> 0:00:38 -> Норм)
# Красивый?) -> 0:03:19 ->
# Новый ординатор тоже его любит? 😂 -> 0:16:45 -> Ofcourse I will refresh my knowledge
# А ты был где-то из этих двух ? -> 0:00:26 -> Был и там и там. Но в Шахдаге был раза 4, катался. А в Туфандаг летом был
# Ну как там день рождения?) -> 0:05:19 -> Выезжаю
# https://www.instagram.com/reel/DDeayBQNyEg/?igsh=NnoxMGR2dWdkcmc3 -> 0:34:20 -> Едешь еще разок вечером?)
# Едешь еще разок вечером?) -> 0:08:36 -> Отсюда пойду
# Как твой вечер? Дошла до отеля президент?) -> 0:14:45 -> Дааа)) Только вот выхожу сейчас от туда 🧖🏻‍♀️
# А твой там как ?) -> 0:37:33 -> Заканчиваем посиделку)
# И как впечатления ? -> 0:12:48 ->
# Не спишь? -> 0:01:59 -> Неа,вот только улеглась в теплую кроватку 😇
# Это шпиц такой прибалдевший ?)) -> 0:02:45 ->
# Это ты сейчас едешь ?) -> 0:00:09 -> Это два часа назад)
# А на завтра такой можно заказать ? -> 0:00:01 -> Но старость не щадит
# Это который мебелью занимается ? -> 0:00:07 -> Да)
# Так может ему в кайф гонять на 5-ке ?) -> 0:00:12 -> Не, у него финансовые проблемы
# А сколько ему лет ? -> 0:01:01 -> поставь несколько будильников. И можешь ещё звук будильника поменять
# Как ты проснулась? Вовремя?) -> 1:17:23 -> Ну так не совсем 🥲
# А ты ? -> 0:26:43 -> В 10. Слава богу звонков не было с утра
# Ну,что там у тебя получается пораньше освободиться? -> 0:05:24 -> Привет
# Выходишь? -> 0:00:08 -> Да
# Как доехала? Водитель норм? -> 0:15:08 -> Да,все хорошо с детским креслом был ))
# Ты не в 8:30 выехала? 😂 -> 0:34:59 -> В 9:45 ))
# Так а что не так пошло ? -> 0:00:01 -> Напарница провела отличный матч
# Себя тоже ? -> 0:01:34 ->
# А сейчас получается уже все ? -> 0:01:39 -> Да, выбыли
# Но вечерняя игра у тебя остается же ? -> 0:00:41 -> Нет
# Лучше до 175 или выше 175? -> 0:20:51 ->
# Если хочешь со мной повыбирать то может попросишь чтоб довезли сюда? Ул Бядули 13к4 -> 0:13:08 -> Тут по дороге очень плохо ловит
# Привет. Как дела? Какой план у нас сегодня? -> 0:43:59 -> Приветик)Все хорошо,я только через где-то освобожусь
# Ты как там ? -> 0:00:17 -> Хорошо 😂😂😂😂
# Подойдешь к Дане ? -> 0:00:06 -> Да, я ничего не планировал на сегодня
# Еще что-то надо ?) -> 0:00:31 -> Как из магазина выйдешь скажу 😂😂
# Такси заказываю ? -> 0:00:05 -> Ваньковича 53
# ? -> 0:00:05 -> Да
# На PlayStation? -> 0:05:25 -> Да)
# Ветрено сегодня там будет. Gusts до 55 км в час. Что думаешь? -> 1:45:53 ->
# Это можно поменять ? -> 0:00:28 -> Нужно построить коммунизм и распространить в США 💪
# ? -> 0:00:05 -> Ой
# За игрушками поедешь ? -> 0:07:48 -> Привезти дядя хотел
# А у тебя на выходных не бывает работа ? -> 0:00:06 -> Это я два года подряд
# Ты там уже стикерпэк из меня сделала? 😂 -> 0:03:08 ->
# Знаешь такой сериал ? -> 0:02:04 -> Нопе
# А есть он на нетфлексе ? -> 0:01:49 -> Давай я лучше тебе свой логин пароль на нетфликс дам 😎
# Как ты доехала? Мама не ругала? -> 0:23:37 -> Сказала,чтобы я свои прогулки осуществляла до 11 часов …
# А у тебя это у кого? У друга в гостях до часу ?) -> 0:01:21 -> Ты можешь ей рассказать обо мне так как ты считаешь нужным. На крайняк у подруги если так сильно не хочешь про меня говорить. Но пожалей свою маму - ты для неё ребенок. Гулять зимой до часу ночи и не отвечать на звонки в час ночи - зачем ты заставляешь её беспокоиться?
# Ты можешь ей рассказать обо мне так как ты считаешь нужным. На крайняк у подруги если так сильно не хочешь про меня говорить. Но пожалей свою маму - ты для неё ребенок. Гулять зимой до часу ночи и не отвечать на звонки в час ночи - зачем ты заставляешь её беспокоиться? -> 0:04:37 -> Вы как всегда правы мой милый Вадим Вячеславович, спросить с Вами нет никакого смысла ))
# Ты тоже всегда нажимаешь кнопку снизу ?) -> 0:00:10 -> Да, ты правильно все видишь))
# Думаешь  плюнуть на все и уехать в Питер ? -> 0:00:10 -> Ну кнопку share нажимаю, а как ещё ))
# А к чему ссылка эта была ? 🔗 -> 0:00:34 -> Просто, вообще ни к чему. Красивые видео. Тем более что ты сказала сегодня что любишь Питер больше Москвы и я подумал тебе отзовется
# Как защитный механизм ? -> 0:00:45 -> Да можешь сделать follow, я добавлюсь. Думаю на нашем этапе знакомства ты уже судишь о мне по мне, а не по моим фоткам в инсте. Поэтому можно добавиться легко
# Или это про другое в твоем понимании ? -> 0:01:58 -> Да. Я это точно знаю, что не уеду. Если я что-то точно знаю наверное лучше об этом сказать как есть, не так ли? И неважно рано или не рано. Если у человека заболевание какое то серьезное - когда об этом лучше сказать? Сразу или подождать? Наверное лучше сразу. То же самое и про меня - я тебе сразу говорю что это для меня не вариант.
#
# А вот ты транслируешь не факты, а гипотетические возможности. Вкидываешь тему «я возможно уеду» и смотришь на мою реакцию. Моя реакция - защитная. Withdrawal. То есть я после таких «вкидываний» начинаю понимать что планировать какое-то средне и долгосрочное будущее смысла точно нет, потому что в игре есть внешние факторы, которые не зависят от меня. А я не хочу что то нам себе напланировать и надумать, а потом из рукава вытаскивается джокер а-ля «Степ пройден, Нью Йорк ждет» И поэтому начинаю смотреть на наше взаимодействие исключительно с точки зрения «здесь и сейчас».
# Или мне надо ответить ? -> 0:00:12 -> Не надо, нет
# И какие ты хочешь,чтобы я сделала выводы ?) -> 0:02:02 -> Я не готов сейчас что то обсуждать
# Как ты ? -> 0:00:27 -> Работаю
# До скольки? -> 0:00:58 -> Можем вечером встретиться начиная с 17 где то
# Ты когда сможешь? Если прям сейчас неудобно, я бы отдохнул 1-2ч. Если можешь сейчас тоже ок -> 0:14:13 -> В принципе могу и сейчас ,но через часика два будет даже  лучше и ты заодно отдохнешь немного ))
# Встретимся в О,Да ? -> 0:00:18 -> О?
# О? -> 0:00:13 -> О,Да !
# Иии? -> 0:06:44 ->
# Такси заказать ? -> 0:04:52 -> Давай с главного входа даны
# What ?? Я всего два мандарина почистила и все выкинула вроде -> 2:42:33 -> Да
# Тоже сегодня ?) -> 0:19:05 -> Да
# Это всегда так работает ? -> 0:00:12 -> Не знаю честно говоря))
# https://youtu.be/uk8PHkryQYk?si=94vJMK9ZcwKANOdW -> 0:00:40 -> Чотенько)
# Так ты почитал перевод ?)) -> 0:00:41 -> Да, спасибо)
# Подожди,это кстати ты на фото ???!!!! -> 0:00:05 -> Да 😂😂😂
# Ты что лазерную коррекцию сделал ? -> 0:00:12 ->
# А какой у тебя минус был ?) -> 0:00:09 -> -3.5
# В Москве делал ? -> 0:00:07 -> Да
# А на каком аппарате не помнишь ? -> 0:00:41 -> Femtolasik
# И с 2020 до сегодняшнего дня только правый на 0,75 ухудшился ? -> 0:00:22 -> https://msk.excimerclinic.ru
# Но тебе же все равно нормально все без очков видно сейчас вдаль ? -> 0:00:29 -> Будешь в Москве съезди в эксимер не поленись, там большой наработанный опыт и диагностика крутая
# Ну если водишь сейчас ,то как ? -> 0:00:10 -> Капилляры на роговице в поиске кислорода слишком на прверхность тянулись
# Роаккутан не принимал ? -> 0:00:54 -> Не
# Это из-за линз ? -> 0:00:07 -> Из-за линз
# А клинически как проявлялось ? -> 0:00:17 -> Сухость, плюс под микроскопом что то заметили
# А очки просто лень было носить ?) -> 0:00:18 -> Именно
# И что ? -> 0:00:06 -> Про птичку
# Не понравился перевод ? -> 0:00:34 -> Да почему понравился/не понравился. Мне главное чтобы трек выходил норм. Для меня это имеет музыкальную ценность, не смысловую
# Покажешь ?) -> 0:00:45 -> Там же на сайте
# Вторая это которая Heart on redial ? -> 0:01:28 -> Ага
# Не прочувствовала японский стиль в треке?) -> 0:06:15 -> Только после того как ты обратил мое внимание
# А Tags sakamoto кто тогда ? -> 0:00:11 -> Точно! Значит sakamoto!!!
# https://www.instagram.com/reel/C_8crMVIO9z/?igsh=ZWR1bW4zZzBsNnN4 -> 6:05:19 -> Доброе утро !!!
# Спишь ? -> 3:33:24 -> Ага. Ток проснулся ))
# Ты случаем не смотрела 3 сезон Lincoln Lawyer кстати?😁 Вчера начал продолжать смотреть херакс до последней серии посмотрено уже 🤣🤣 -> 0:27:40 -> Ну ты даешь Соня !!!
# Много людей ? -> 0:00:16 ->
# Ты на такси поехала? -> 0:00:02 ->
# Знаешь этот прикол?) -> 0:00:03 -> Вадим Калабин
# Делаешь одолжение ? -> 0:00:00 -> А что у вас там гулять…
# Предложение мне сделаешь? 😅 -> 0:00:06 -> Я борд закину только
# Почему тебе дома не кушается? Мисс Селеба?)) -> 0:00:18 -> Потому что я хочу с тобой
# Как я к тебе отношусь ? -> 0:00:29 -> Хорошо) С теплом
# Т.е ты специально так делал ? -> 0:00:16 -> Нет
# Зол на кожуру от мандаринок ? -> 0:03:51 ->
# Какая систематичность ?? Кружку помыть или поставить в посудомойку? Если для тебя это было так важно,почему ты мне об этом не сказал, когда я у тебя была,если это тебя бесило и триггерило ? Или просто нормально об этом сказать -> 0:04:26 ->
# Я так понимаю идея с прогулкой отменилась? 😄 -> 0:00:22 -> А ты только и рад этому
# А потом до ночи занят ? -> 0:00:40 -> Не знаю до ночи или раньше освобожусь
# На свидание ?) -> 0:00:22 -> Я клянусь ждал этого вопроса 😂😂😂
# Знаешь что оно делает ? -> 0:03:45 -> Я знаю амигдала
# Сколько еще там будешь ? -> 0:02:38 -> Уехал
# Вечером перед теннисом прогуляемся? -> 0:38:21 -> Шалом?)) Я смотрю ты тоже не можешь, чтобы не уколоть
# https://www.instagram.com/reel/DEHeCUaIcGU/?igsh=ZnVlbnpyMXFrZGc2 -> 0:41:17 -> Мне каждый раз писать «не можешь не уколоть?»))
# Я смогу выйти на прогулку в течение дня. Ты как? -> 2:13:43 -> Привет
# Удобно будет встретиться в новой Боровой прогуляться ? -> 0:07:51 -> В какой новой Боровой? О чем ты? 😂😂
# Ты в мою сторону идешь ? -> 0:00:15 -> Ну да
# Ты где ? -> 7:08:09 -> It was lovely meeting you, hugging you, watching movie together and making food. Like in good old days..
# Почему ?) -> 0:01:40 ->
# https://www.instagram.com/reel/DAEBCUtsFqv/?igsh=MWZueHJ4ajlwejF1MQ== -> 0:02:00 -> Посмотрел видео. 99% лайков  - женщины)
# А как с натурой и мои сообщением связано? -> 0:00:15 -> То что вот моя философия по жизни
# Ты забрал карту с Альфа private ?) -> 0:02:14 -> Да)
# В какой fixPrice ? -> 0:00:28 -> Где семь пятниц
# Какого цвета звезда лучше ? -> 0:00:19 -> Белого )
# Такое? -> 0:01:21 -> Нет,гирлянда такая модная)
# А чего спрашивал ?🤣 -> 0:02:15 -> Я уже тут возьму какие-то, спасибо
# Как празднуете? -> 0:16:21 ->
# А вы ?) -> 0:22:30 ->
# https://www.instagram.com/reel/DDuwSWzMEtt/?igsh=MTJpN3lsZzNhaDV3ag== -> 5:32:01 ->
# Фотка про кино или атмосферу? Атмосфера кайф 🥰 -> 0:47:36 -> И про то и про другое )
# Кино угадал ? -> 0:06:14 -> Не-а)

# %%
def build_distribution(data, step, left_th, right_th):
    new_data = []
    for ts in data:
        if left_th <= ts <= right_th:
            new_data.append(ts)

    data = new_data

    bins = max(data) // step + 1
    dist = [0] * bins
    for x in data:
        dist[x // step] += 1

    log_dist = []
    i = 0
    bin_size = 1
    while i < len(dist):
        next_i = i + bin_size
        res = 0
        while i < next_i and i < len(dist):
            res += dist[i]
            i += 1
        log_dist.append(res)
        bin_size *= 1.1

    for i in range(len(log_dist)):
        log_dist[i] /= len(data)

    return log_dist

step = 1
left_threshold = 0
right_threshold = 200000

from statistics import median, mean

def filter_th(dt, left_th, right_th):
    res = []
    for x in dt:
        if left_th <= x <= right_th:
            res.append(x)
    return res

right_slice = 5000

her_dists = build_distribution(diffs[0], step, left_threshold, right_threshold)[:right_slice]
my_dists = build_distribution(diffs[1], step, left_threshold, right_threshold)[:right_slice]
print("username: her median:", median(filter_th(diffs[0], left_threshold, right_threshold)),
            "my median:", median(filter_th(diffs[1], left_threshold, right_threshold)))
print("username: her mean:", mean(filter_th(diffs[0], left_threshold, right_threshold)),
            "my mean:", mean(filter_th(diffs[1], left_threshold, right_threshold)))
# Out:
# username: her median: 159.0 my median: 35.5
# username: her mean: 6424.25 my mean: 1721.7181818181818

# %%
def get_label_by_sec(sec):
    ss = sec % 60
    mm = (sec // 60) % 60
    hh = sec // 60 // 60

    res = ""
    if hh > 0:
        return str(hh) + "h"
    if mm > 0:
        if res:
            res += ' '
        return str(mm) + "m"

    if ss > 0:
        if res:
            res += ' '
        return str(ss) + "s"



x = []
labels = []
k = 1.1
bin_size = 1
curr = 0
last_label = -10
for i in range(100):
    if last_label + 5 < i:
        x.append(i)
        labels.append(get_label_by_sec(int(curr)))
        last_label = i
    curr += bin_size
    bin_size *= k

print(x, labels)
# Out:
# [0, 6, 12, 18, 24, 30, 36, 42, 48, 54, 60, 66, 72, 78, 84, 90, 96] [None, '7s', '21s', '45s', '1m', '2m', '4m', '8m', '16m', '28m', '50m', '1h', '2h', '4h', '8h', '14h', '26h']

# %%
from scipy.interpolate import make_interp_spline, BSpline
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.pyplot import figure
figure(num=None, figsize=(16, 6), dpi=80, facecolor='w', edgecolor='k')



figure(num=None, figsize=(16, 6), dpi=80, facecolor='w', edgecolor='k')
plt.bar([i for i in range(len(her_dists))], her_dists, color='blue', alpha=0.5)
plt.bar([i for i in range(len(my_dists))], my_dists, color='orange', alpha=0.5)
plt.xticks(x, labels, rotation='horizontal')
plt.legend(['her', 'me'])
plt.show()
